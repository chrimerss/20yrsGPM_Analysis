# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
h5= h5py.File('test_sample.HDF5','r')

# %%
h5.keys()
# Out:
# <KeysViewHDF5 ['Grid']>

# %%
h5['Grid'].keys()
# Out:
# <KeysViewHDF5 ['nv', 'lonv', 'latv', 'time', 'lon', 'lat', 'time_bnds', 'lon_bnds', 'lat_bnds', 'precipitationCal', 'precipitationUncal', 'randomError', 'HQprecipitation', 'HQprecipSource', 'HQobservationTime', 'IRprecipitation', 'IRkalmanFilterWeight', 'probabilityLiquidPrecipitation', 'precipitationQualityIndex']>

# %%
grided_map= h5['Grid']
lons= np.array(h5['Grid/lon'])
lats= np.array(h5['Grid/lat'])
data= np.array(h5['Grid/precipitationCal']).transpose()

# %%
xmin, ymin, xmax, ymax = [lons.min(), lats.min(), lons.max(), lats.max()]
xres, yres, _= data.shape
ncol, nrow= int((xmax-xmin)//xres), int((ymax-ymin)//yres)

# %%
xmax
# Out:
# 179.95

# %%
from osgeo import gdal
from affine import Affine

# %%
xy_to_raster_affine = Affine.from_gdal(xmin, xres, 0, ymax, 0, -yres)

# %%
xy_to_raster_affine
# Out:
# Affine(1800.0, 0.0, -179.9499969482422,
#        0.0, -3600.0, 89.94999694824219)

# %%
from PIL import Image
data= np.clip(data, 0, np.inf)
# normalization
data= (data/ data.max())**1.
img_arr= np.uint8(data*2**8)
Image.fromarray(img_arr[:,:,-1], 'L')
# Out:
# <PIL.Image.Image image mode=L size=3600x1800 at 0x11EA1A890>

# %%
2**8
# Out:
# 256
